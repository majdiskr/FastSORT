# %% [markdown]
# <a href="https://colab.research.google.com/github/majdiskr/FastSORT/blob/main/strongSORT_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/majdiskr/greatsort.git
# Out:
# Cloning into 'greatsort'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 41 (delta 0), reused 41 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 718.27 KiB | 21.77 MiB/s, done.

# %%
# !pip install torch torchvision torchaudio opencv-python scipy scikit-learn==0.19.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 57.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for scikit-learn
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (scikit-learn)

# %%
# !pip install scipy

# %%
# Example for Colab or terminal:
# !wget http://motchallenge.net/data/MOT17.zip
# Out:
# --2024-09-09 06:24:17--  http://motchallenge.net/data/MOT17.zip
# Resolving motchallenge.net (motchallenge.net)... 131.159.19.34, 2a09:80c0:18::1034
# Connecting to motchallenge.net (motchallenge.net)|131.159.19.34|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://motchallenge.net/data/MOT17.zip [following]
# --2024-09-09 06:24:17--  https://motchallenge.net/data/MOT17.zip
# Connecting to motchallenge.net (motchallenge.net)|131.159.19.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5860214001 (5.5G) [application/zip]
# Saving to: ‘MOT17.zip’
#
# MOT17.zip           100%[===================>]   5.46G  16.8MB/s    in 5m 7s
#
# 2024-09-09 06:29:25 (18.2 MB/s) - ‘MOT17.zip’ saved [5860214001/5860214001]
#
# Archive:  MOT17.zip
# checkdir:  cannot create extraction directory: /path/to/extract
#            No such file or directory

# %%
# !unzip MOT17.zip -d /content/data/dyh/data/MOTChallenge
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000333.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/001039.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000327.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000441.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000496.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000482.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000509.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000521.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000247.jpg
#   inflating: /content/data/dyh/data/MOTChallenge/MOT17/train/MOT17-04-DPM/img1/000253.jpg
# ...

# %%
# !ls /data/dyh/data/MOTChallenge/MOT17/train/MOT17-02-FRCNN/img1
# Out:
# ls: cannot access '/data/dyh/data/MOTChallenge/MOT17/train/MOT17-02-FRCNN/img1': No such file or directory

# %%
# !cd /content/greatsort/StrongSORT-master
# !python /content/greatsort/StrongSORT-master/strong_sort.py MOT17 val
# Out:
# processing the 1th video MOT17-02-FRCNN...
# Traceback (most recent call last):
#   File "/content/greatsort/StrongSORT-master/strong_sort.py", line 24, in <module>
#     run(
#   File "/content/greatsort/StrongSORT-master/deep_sort_app.py", line 161, in run
#     seq_info = gather_sequence_info(sequence_dir, detection_file)
#   File "/content/greatsort/StrongSORT-master/deep_sort_app.py", line 47, in gather_sequence_info
#     for f in os.listdir(image_dir)}
# FileNotFoundError: [Errno 2] No such file or directory: '/data/dyh/data/MOTChallenge/MOT17/train/MOT17-02-FRCNN/img1'

# %%
# !python strong_sort.py MOT20 test --BoT --ECC --NSA --EMA --MC --woC --AFLink --GSI
# Out:
# Traceback (most recent call last):
#   File "/content/StrongSORT/strong_sort.py", line 11, in <module>
#     from opts import opt
#   File "/content/StrongSORT/opts.py", line 153, in <module>
#     opt = opts().parse()
#   File "/content/StrongSORT/opts.py", line 144, in parse
#     opt.ecc = json.load(open(path_ECC))
# FileNotFoundError: [Errno 2] No such file or directory: '/data/dyh/results/StrongSORT_Git/MOT20_ECC_test.json'

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a29085f6-e2da-4579-beb4-638f1f9a8652" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a29085f6-e2da-4579-beb4-638f1f9a8652">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...

# %%
# !pip install torch torchvision torchaudio  # PyTorch and related libraries
# !pip install numpy opencv-python tqdm  # Common libraries
# !pip install cython scipy  # Additional libraries that might be required

# %%
# Step 1: Navigate to the StrongSORT directory
# %cd /content/StrongSORT

# Step 2: Correctly modify the import statement in 'linear_assignment.py'
# This will ensure the correct replacement of the line
# !sed -i 's/from sklearn.utils.linear_assignment_/from scipy.optimize import linear_sum_assignment as linear_assignment/' deep_sort/linear_assignment.py

# Step 3: Run the StrongSORT script
# !python strong_sort.py MOT17 val
# Out:
# /content/StrongSORT
# Traceback (most recent call last):
#   File "/content/StrongSORT/strong_sort.py", line 12, in <module>
#     from deep_sort_app import run
#   File "/content/StrongSORT/deep_sort_app.py", line 14, in <module>
#     from deep_sort.tracker import Tracker
#   File "/content/StrongSORT/deep_sort/tracker.py", line 5, in <module>
#     from . import linear_assignment
#   File "/content/StrongSORT/deep_sort/linear_assignment.py", line 4
#     from scipy.optimize import linear_sum_assignment as linear_assignment import linear_assignment
#                                                                           ^^^^^^
# SyntaxError: invalid syntax

# %%
# !python /content/StrongSORT/strong_sort.py --source path_to_video.mp4 --config_strongsort path_to_config.yaml
# Out:
# usage: strong_sort.py [-h] [--BoT] [--ECC] [--NSA] [--EMA] [--MC] [--woC] [--AFLink] [--GSI]
#                       [--root_dataset ROOT_DATASET] [--path_AFLink PATH_AFLINK]
#                       [--dir_save DIR_SAVE] [--EMA_alpha EMA_ALPHA] [--MC_lambda MC_LAMBDA]
#                       dataset mode
# strong_sort.py: error: unrecognized arguments: --source --config_strongsort
